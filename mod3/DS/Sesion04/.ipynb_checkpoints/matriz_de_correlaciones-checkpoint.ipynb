# %% [markdown]
# ## Reto 2: Matriz de correlaciones
#
# ### 1. Objetivos:
#     - Aprender a generar e interpretar una matriz de correlaciones
#
# ---
#
# ### 2. Desarrollo:

# %% [markdown]
# Para este Reto vamos a utilizar un conjunto de datos llamado 'wine_quality_red-clean.csv'. Este dataset tiene datos acerca de diversos tipos de vino rojo. Incluye datos acerca de la composición química de los vinos y una variable 'quality' que es una evaluación de la calidad del vino que va del 1 al 10.
#
# Aquí esta [el link](https://archive.ics.uci.edu/ml/datasets/wine+quality) de donde proviene este dataset.

# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("https://raw.githubusercontent.com/beduExpert/B2-Analisis-de-Datos-con-Python-2020-Santander/main/Datasets/wine_quality_red-clean.csv", index_col=0)

df.head()
# Out:
#    fixed_acidity  volatile_acidity  citric_acid  ...  sulphates  alcohol  quality
# 0            7.4              0.70         0.00  ...       0.56      9.4        5
# 1            7.8              0.88         0.00  ...       0.68      9.8        5
# 2            7.8              0.76         0.04  ...       0.65      9.8        5
# 3           11.2              0.28         0.56  ...       0.58      9.8        6
# 4            7.4              0.70         0.00  ...       0.56      9.4        5
#
# [5 rows x 12 columns]

# %%
new_df = pd.DataFrame(index=df.columns)
new_df = pd.concat([df.max(), df.min(), df.mean(), df.median(), df.std()], axis=1)
new_df.columns = ["Max", "Min", "Mean", "Median", "Std"]
new_df
# Out:
#                             Max      Min       Mean    Median        Std
# fixed_acidity          15.90000  4.60000   8.319637   7.90000   1.741096
# volatile_acidity        1.58000  0.12000   0.527821   0.52000   0.179060
# citric_acid             1.00000  0.00000   0.270976   0.26000   0.194801
# residual_sugar         15.50000  0.90000   2.538806   2.20000   1.409928
# chlorides               0.61100  0.01200   0.087467   0.07900   0.047065
# free_sulfur_dioxide    72.00000  1.00000  15.874922  14.00000  10.460157
# total_sulfur_dioxide  289.00000  6.00000  46.467792  38.00000  32.895324
# density                 1.00369  0.99007   0.996747   0.99675   0.001887
# pH                      4.01000  2.74000   3.311113   3.31000   0.154386
# sulphates               2.00000  0.33000   0.658149   0.62000   0.169507
# alcohol                14.90000  8.40000  10.422983  10.20000   1.065668
# quality                 8.00000  3.00000   5.636023   6.00000   0.807569

# %% [markdown]
# Vamos a explorar las relaciones que existen entre estas variables. Para esto, genera un heatmap para visualizar el coeficiente de correlación de Pearson entre todas las variables del dataset. Añade un título y utiliza [la documentación](https://seaborn.pydata.org/generated/seaborn.heatmap.html) para modificar la gráfica a tu gusto y hacerla más atractiva y comprensible. Puedes modificar el grosor de las líneas entre los cuadros, el color de los cuadros, el rango total del espectro de colores, etc. Después de tener lista tu visualización, responde las siguientes preguntas y coméntalas con tus compañeros y la experta:
#
# 1. ¿Qué variables no tienen una correlación lineal entre ellas?
# 2. ¿Qué variables tienen correlaciones positivas?
# 3. ¿Qué par de variables tiene la mayor correlación positiva?
# 4. ¿Qué variables tienen correlaciones negativas?
# 5. ¿Qué par de variables tiene la mayor correlación negativa?
# 6. ¿Tienes algunas hipótesis acerca de por qué existen estas correlaciones (o porque no existen)?

# %%
corr_mat = df.corr()
plt.figure(figsize=(10, 8))
ax = sns.heatmap(corr_mat, vmin=-1, vmax=1, annot=True, cmap="Spectral", linewidths=1);

# %%
# ¿Qué variables no tienen una correlación lineal entre ellas?
print(corr_mat[abs(corr_mat) < 0.2])

# ¿Qué variables tienen correlaciones positivas?
print(corr_mat[corr_mat > 0.0])

# ¿Qué par de variables tiene la mayor correlación positiva?


# ¿Qué variables tienen correlaciones negativas?
print(corr_mat[corr_mat < 0.0])

# ¿Qué par de variables tiene la mayor correlación negativa?

# ¿Tienes algunas hipótesis acerca de por qué existen estas correlaciones (o porque no existen)?
# Out:
#                       fixed_acidity  volatile_acidity  ...   alcohol   quality
# fixed_acidity                   NaN               NaN  ... -0.061668  0.124052
# volatile_acidity                NaN               NaN  ...       NaN       NaN
# citric_acid                     NaN               NaN  ...  0.109903       NaN
# residual_sugar             0.114777          0.001918  ...  0.042075  0.013732
# chlorides                  0.093705          0.061298  ...       NaN -0.128907
# free_sulfur_dioxide       -0.153794         -0.010504  ... -0.069408 -0.050656
# total_sulfur_dioxide      -0.113181          0.076470  ...       NaN -0.185100
# density                         NaN          0.022026  ...       NaN -0.174919
# pH                              NaN               NaN  ...       NaN -0.057731
# sulphates                  0.183006               NaN  ...  0.093595       NaN
# alcohol                   -0.061668               NaN  ...       NaN       NaN
# quality                    0.124052               NaN  ...       NaN       NaN
#
# [12 rows x 12 columns]
#                       fixed_acidity  volatile_acidity  ...   alcohol   quality
# fixed_acidity              1.000000               NaN  ...       NaN  0.124052
# volatile_acidity                NaN          1.000000  ...       NaN       NaN
# citric_acid                0.671703               NaN  ...  0.109903  0.226373
# residual_sugar             0.114777          0.001918  ...  0.042075  0.013732
# chlorides                  0.093705          0.061298  ...       NaN       NaN
# free_sulfur_dioxide             NaN               NaN  ...       NaN       NaN
# total_sulfur_dioxide            NaN          0.076470  ...       NaN       NaN
# density                    0.668047          0.022026  ...       NaN       NaN
# pH                              NaN          0.234937  ...  0.205633       NaN
# sulphates                  0.183006               NaN  ...  0.093595  0.251397
# alcohol                         NaN               NaN  ...  1.000000  0.476166
# quality                    0.124052               NaN  ...  0.476166  1.000000
#
# [12 rows x 12 columns]
#                       fixed_acidity  volatile_acidity  ...   alcohol   quality
# fixed_acidity                   NaN         -0.256131  ... -0.061668       NaN
# volatile_acidity          -0.256131               NaN  ... -0.202288 -0.390558
# citric_acid                     NaN         -0.552496  ...       NaN       NaN
# residual_sugar                  NaN               NaN  ...       NaN       NaN
# chlorides                       NaN               NaN  ... -0.221141 -0.128907
# free_sulfur_dioxide       -0.153794         -0.010504  ... -0.069408 -0.050656
# total_sulfur_dioxide      -0.113181               NaN  ... -0.205654 -0.185100
# density                         NaN               NaN  ... -0.496180 -0.174919
# pH                        -0.682978               NaN  ...       NaN -0.057731
# sulphates                       NaN         -0.260987  ...       NaN       NaN
# alcohol                   -0.061668         -0.202288  ...       NaN       NaN
# quality                         NaN         -0.390558  ...       NaN       NaN
#
# [12 rows x 12 columns]
