# %%
import pandas as pd
import numpy as np
from sklearn.linear_model import LinearRegression
import os
import matplotlib.pyplot as plt
import seaborn as sns
import mpl_toolkits

# %%
dataset = pd.read_csv("kc_house_data.csv")

# %%
dataset.head(15)
# Out:
#             id             date      price  bedrooms  bathrooms  sqft_living  \
# 0   7129300520  20141013T000000   221900.0         3       1.00         1180
# 1   6414100192  20141209T000000   538000.0         3       2.25         2570
# 2   5631500400  20150225T000000   180000.0         2       1.00          770
# 3   2487200875  20141209T000000   604000.0         4       3.00         1960
# 4   1954400510  20150218T000000   510000.0         3       2.00         1680
# 5   7237550310  20140512T000000  1225000.0         4       4.50         5420
# 6   1321400060  20140627T000000   257500.0         3       2.25         1715
# 7   2008000270  20150115T000000   291850.0         3       1.50         1060
# 8   2414600126  20150415T000000   229500.0         3       1.00         1780
# 9   3793500160  20150312T000000   323000.0         3       2.50         1890
# 10  1736800520  20150403T000000   662500.0         3       2.50         3560
# ...

# %%
print(dataset.date)
# Out:
# 0        20141013T000000
# 1        20141209T000000
# 2        20150225T000000
# 3        20141209T000000
# 4        20150218T000000
#               ...
# 21608    20140521T000000
# 21609    20150223T000000
# 21610    20140623T000000
# 21611    20150116T000000
# 21612    20141015T000000
# Name: date, Length: 21613, dtype: object

# %%
dataset.describe()
# Out:
#                  id         price      bedrooms     bathrooms   sqft_living  \
# count  2.161300e+04  2.161300e+04  21613.000000  21613.000000  21613.000000
# mean   4.580302e+09  5.400881e+05      3.370842      2.114757   2079.899736
# std    2.876566e+09  3.671272e+05      0.930062      0.770163    918.440897
# min    1.000102e+06  7.500000e+04      0.000000      0.000000    290.000000
# 25%    2.123049e+09  3.219500e+05      3.000000      1.750000   1427.000000
# 50%    3.904930e+09  4.500000e+05      3.000000      2.250000   1910.000000
# 75%    7.308900e+09  6.450000e+05      4.000000      2.500000   2550.000000
# max    9.900000e+09  7.700000e+06     33.000000      8.000000  13540.000000
#
#            sqft_lot        floors    waterfront          view     condition  \
# count  2.161300e+04  21613.000000  21613.000000  21613.000000  21613.000000
# mean   1.510697e+04      1.494309      0.007542      0.234303      3.409430
# ...

# %%
price = dataset['price']
space = dataset['sqft_living']

# %%
# Barplot habitaciones

dataset["bedrooms"].value_counts().plot(kind="bar")
plt.title("número de habitaciones")
plt.xlabel("habitaciones")
plt.ylabel("Frecuencia")
sns.despine
# Out:
# <function seaborn.utils.despine(fig=None, ax=None, top=True, right=True, left=False, bottom=False, offset=None, trim=False)>

# %%
plt.figure(figsize=(10,10))
sns.jointplot(x=dataset.lat.values, y=dataset.long.values, size=10)
plt.xlabel("latitud")
plt.yalbel("Longitud")
plt.show()
# Out:
# C:\Users\Pelu\Anaconda3\lib\site-packages\seaborn\axisgrid.py:2015: UserWarning: The `size` parameter has been renamed to `height`; please update your code.
#   warnings.warn(msg, UserWarning)
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-7-99b9cb4303cc> in <module>
#       2 sns.jointplot(x=dataset.lat.values, y=dataset.long.values, size=10)
#       3 plt.xlabel("latitud")
# ----> 4 plt.yalbel("Longitud")
#       5 plt.show()
#
# AttributeError: module 'matplotlib.pyplot' has no attribute 'yalbel'

# %%
# Pies cuadrados
plt.scatter(dataset.price, dataset.sqft_living)
plt.title("precio vs Pies Cuadrados")
# Out:
# Text(0.5, 1.0, 'precio vs Pies Cuadrados')

# %%
price = dataset["price"]
train1 = dataset.drop(["id","price","date"], axis =1)

# %%
train1.head(10)
# Out:
#    bedrooms  bathrooms  sqft_living  sqft_lot  floors  waterfront  view  \
# 0         3       1.00         1180      5650     1.0           0     0
# 1         3       2.25         2570      7242     2.0           0     0
# 2         2       1.00          770     10000     1.0           0     0
# 3         4       3.00         1960      5000     1.0           0     0
# 4         3       2.00         1680      8080     1.0           0     0
# 5         4       4.50         5420    101930     1.0           0     0
# 6         3       2.25         1715      6819     2.0           0     0
# 7         3       1.50         1060      9711     1.0           0     0
# 8         3       1.00         1780      7470     1.0           0     0
# 9         3       2.50         1890      6560     2.0           0     0
#
#    condition  grade  sqft_above  sqft_basement  yr_built  yr_renovated  \
# 0          3      7        1180              0      1955             0
# ...

# %%
from sklearn.model_selection import train_test_split

# %%
x_train, x_test, y_train, y_test = train_test_split(train1,price, test_size =.10, random_state =25)

# %%
regressor = LinearRegression()
regressor.fit(x_train, y_train)
# Out:
# LinearRegression()

# %%
# Estudiemos un poquito la r^2

regressor.score(x_test,y_test)
# Out:
# 0.6791625453275065
